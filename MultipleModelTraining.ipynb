# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, label_binarize
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_curve, auc, classification_report, confusion_matrix, roc_auc_score
)

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB

# ================== Load Data ==================
df = pd.read_csv("DeveloperDataset.csv")

selected_features = [
    'Database Fundamentals', 'Computer Architecture',
    'Distributed Computing Systems', 'Cyber Security',
    'Networking', 'Software Development',
    'Programming Skills', 'Project Management',
    'Computer Forensics Fundamentals',
    'Openness to Change', 'Conscientousness',
    'Extraversion', 'Agreeableness', 'Emotional_Range'
]

X = df[selected_features]
y = df['Role']

# Encode target
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
classes = label_encoder.classes_

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# ================== Models to Compare ==================
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42),
    "SVM": SVC(probability=True, random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=200, random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=200, random_state=42),
    "Naive Bayes": GaussianNB()
}

results = []

# ================== Train & Evaluate ==================
for name, model in models.items():
    # Train with scaled or unscaled data
    if name in ["Logistic Regression", "SVM", "Naive Bayes"]:
        model.fit(X_train_scaled, y_train)
        y_pred = model.predict(X_test_scaled)
        y_proba = model.predict_proba(X_test_scaled)
    else:
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        y_proba = model.predict_proba(X_test)

    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, average="weighted", zero_division=0)
    rec = recall_score(y_test, y_pred, average="weighted")
    f1 = f1_score(y_test, y_pred, average="weighted")
    auc_score = roc_auc_score(y_test, y_proba, multi_class="ovr", average="weighted")

    results.append((name, acc, prec, rec, f1, auc_score))

    # Print detailed classification report
    print("="*70)
    print(f"Model: {name}")
    print(f"Accuracy: {acc:.4f}")
    print(f"Precision: {prec:.4f}")
    print(f"Recall: {rec:.4f}")
    print(f"F1-score: {f1:.4f}")
    print(f"AUC-ROC: {auc_score:.4f}")
    print("Classification Report:")
    print(classification_report(y_test, y_pred, target_names=classes))

    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=classes, yticklabels=classes)
    plt.title(f"Confusion Matrix - {name}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

    # ROC Curve (One-vs-Rest for multiclass)
    y_test_bin = label_binarize(y_test, classes=np.arange(len(classes)))
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(len(classes)):
        fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_proba[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Plot ROC curve
    plt.figure(figsize=(6, 5))
    for i in range(len(classes)):
        plt.plot(fpr[i], tpr[i], lw=2,
                 label=f"{classes[i]} (AUC = {roc_auc[i]:.2f})")
    plt.plot([0, 1], [0, 1], "k--", lw=2)
    plt.title(f"ROC Curve - {name}")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.legend(loc="lower right")
    plt.show()

# ================== Results Summary ==================
results_df = pd.DataFrame(results, columns=["Model", "Accuracy", "Precision", "Recall", "F1-score", "AUC-ROC"])
print("\n\nOverall Comparison:")
print(results_df)
# Out:
# ======================================================================
# Model: Logistic Regression
# Accuracy: 0.7914
# Precision: 0.7968
# Recall: 0.7914
# F1-score: 0.7740
# AUC-ROC: 0.9667
# Classification Report:
#                                  precision    recall  f1-score   support
#
#                AI ML Specialist       0.57      0.80      0.66       216
#                  API Specialist       0.99      1.00      1.00       108
#    Application Support Engineer       0.99      1.00      1.00       108
#                Business Analyst       0.96      0.22      0.36       108
#      Customer Service Executive       0.64      1.00      0.78       108
#       Cyber Security Specialist       0.98      1.00      0.99       108
#          Database Administrator       1.00      1.00      1.00       108
#               Graphics Designer       0.61      0.47      0.53       108
#               Hardware Engineer       0.99      1.00      1.00       108
#               Helpdesk Engineer       0.44      0.44      0.44       108
# Information Security Specialist       1.00      1.00      1.00       108
#             Networking Engineer       0.99      1.00      1.00       108
#                 Project Manager       0.99      1.00      1.00       108
#              Software Developer       0.96      1.00      0.98       108
#                 Software tester       0.56      0.57      0.57       108
#                Technical Writer       0.30      0.15      0.20       108
#
#                        accuracy                           0.79      1836
#                       macro avg       0.81      0.79      0.78      1836
#                    weighted avg       0.80      0.79      0.77      1836
# ======================================================================
# Model: SVM
# Accuracy: 0.8807
# Precision: 0.8876
# Recall: 0.8807
# F1-score: 0.8771
# AUC-ROC: 0.9950
# Classification Report:
#                                  precision    recall  f1-score   support
#
#                AI ML Specialist       0.69      0.88      0.77       216
#                  API Specialist       0.99      1.00      1.00       108
#    Application Support Engineer       0.97      1.00      0.99       108
#                Business Analyst       0.71      0.44      0.55       108
#      Customer Service Executive       0.98      0.99      0.99       108
#       Cyber Security Specialist       0.96      1.00      0.98       108
#          Database Administrator       0.96      1.00      0.98       108
#               Graphics Designer       0.99      0.73      0.84       108
#               Hardware Engineer       0.98      0.99      0.99       108
#               Helpdesk Engineer       0.82      0.78      0.80       108
# Information Security Specialist       1.00      1.00      1.00       108
#             Networking Engineer       0.96      1.00      0.98       108
#                 Project Manager       0.97      0.99      0.98       108
#              Software Developer       0.91      0.97      0.94       108
#                 Software tester       0.61      0.75      0.68       108
#                Technical Writer       0.90      0.56      0.69       108
#
#                        accuracy                           0.88      1836
#                       macro avg       0.90      0.88      0.88      1836
#                    weighted avg       0.89      0.88      0.88      1836
# ======================================================================
# Model: Random Forest
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1-score: 1.0000
# AUC-ROC: 1.0000
# Classification Report:
#                                  precision    recall  f1-score   support
#
#                AI ML Specialist       1.00      1.00      1.00       216
#                  API Specialist       1.00      1.00      1.00       108
#    Application Support Engineer       1.00      1.00      1.00       108
#                Business Analyst       1.00      1.00      1.00       108
#      Customer Service Executive       1.00      1.00      1.00       108
#       Cyber Security Specialist       1.00      1.00      1.00       108
#          Database Administrator       1.00      1.00      1.00       108
#               Graphics Designer       1.00      1.00      1.00       108
#               Hardware Engineer       1.00      1.00      1.00       108
#               Helpdesk Engineer       1.00      1.00      1.00       108
# Information Security Specialist       1.00      1.00      1.00       108
#             Networking Engineer       1.00      1.00      1.00       108
#                 Project Manager       1.00      1.00      1.00       108
#              Software Developer       1.00      1.00      1.00       108
#                 Software tester       1.00      1.00      1.00       108
#                Technical Writer       1.00      1.00      1.00       108
#
#                        accuracy                           1.00      1836
#                       macro avg       1.00      1.00      1.00      1836
#                    weighted avg       1.00      1.00      1.00      1836
# ======================================================================
# Model: Gradient Boosting
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1-score: 1.0000
# AUC-ROC: 1.0000
# Classification Report:
#                                  precision    recall  f1-score   support
#
#                AI ML Specialist       1.00      1.00      1.00       216
#                  API Specialist       1.00      1.00      1.00       108
#    Application Support Engineer       1.00      1.00      1.00       108
#                Business Analyst       1.00      1.00      1.00       108
#      Customer Service Executive       1.00      1.00      1.00       108
#       Cyber Security Specialist       1.00      1.00      1.00       108
#          Database Administrator       1.00      1.00      1.00       108
#               Graphics Designer       1.00      1.00      1.00       108
#               Hardware Engineer       1.00      1.00      1.00       108
#               Helpdesk Engineer       1.00      1.00      1.00       108
# Information Security Specialist       1.00      1.00      1.00       108
#             Networking Engineer       1.00      1.00      1.00       108
#                 Project Manager       1.00      1.00      1.00       108
#              Software Developer       1.00      1.00      1.00       108
#                 Software tester       1.00      1.00      1.00       108
#                Technical Writer       1.00      1.00      1.00       108
#
#                        accuracy                           1.00      1836
#                       macro avg       1.00      1.00      1.00      1836
#                    weighted avg       1.00      1.00      1.00      1836
# ======================================================================
# Model: Naive Bayes
# Accuracy: 0.7669
# Precision: 0.7852
# Recall: 0.7669
# F1-score: 0.7608
# AUC-ROC: 0.9653
# Classification Report:
#                                  precision    recall  f1-score   support
#
#                AI ML Specialist       0.41      0.56      0.47       216
#                  API Specialist       1.00      1.00      1.00       108
#    Application Support Engineer       1.00      1.00      1.00       108
#                Business Analyst       0.32      0.39      0.35       108
#      Customer Service Executive       0.70      1.00      0.82       108
#       Cyber Security Specialist       1.00      1.00      1.00       108
#          Database Administrator       1.00      1.00      1.00       108
#               Graphics Designer       0.78      0.36      0.49       108
#               Hardware Engineer       1.00      1.00      1.00       108
#               Helpdesk Engineer       0.77      0.45      0.57       108
# Information Security Specialist       1.00      1.00      1.00       108
#             Networking Engineer       1.00      1.00      1.00       108
#                 Project Manager       1.00      1.00      1.00       108
#              Software Developer       1.00      0.98      0.99       108
#                 Software tester       0.46      0.55      0.50       108
#                Technical Writer       0.51      0.18      0.26       108
#
#                        accuracy                           0.77      1836
#                       macro avg       0.81      0.78      0.78      1836
#                    weighted avg       0.79      0.77      0.76      1836
# Overall Comparison:
#                  Model  Accuracy  Precision    Recall  F1-score   AUC-ROC
# 0  Logistic Regression  0.791394   0.796814  0.791394  0.774043  0.966670
# 1                  SVM  0.880719   0.887575  0.880719  0.877050  0.995010
# 2        Random Forest  1.000000   1.000000  1.000000  1.000000  1.000000
# 3    Gradient Boosting  1.000000   1.000000  1.000000  1.000000  1.000000
# 4          Naive Bayes  0.766885   0.785238  0.766885  0.760815  0.965293
